# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
# Expectations from this project are:
#
# * Understand the dataset provided
# * Clean the data and interpret it to provide business insights
# * Prepare a presentation on the insights from the dataset
# * Upload the notebook to Github
#
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# Here's the presentation: [Ames Housing Dataset Exploration](https://docs.google.com/presentation/d/19AUUbKB8Gd_KbMT9fJBre7i5s5QBS7cPBDOY8j8rYKc/edit?usp=sharing)

# %%
# !dir
# pip install numpy
# import pandas library
import pandas as pd

import numpy as np

#declare 
df= pd.read_csv('data/data_description.txt', sep='\n')
df

# data = np.loadtxt('data\data_description.txt')
# data
# Out:
#     MSSubClass: Identifies the type of dwelling involved in the sale.\t
# 0                  20\t1-STORY 1946 & NEWER ALL STYLES
# 1                             30\t1-STORY 1945 & OLDER
# 2                40\t1-STORY W/FINISHED ATTIC ALL AGES
# 3                45\t1-1/2 STORY - UNFINISHED ALL AGES
# 4                    50\t1-1/2 STORY FINISHED ALL AGES
# ..                                                 ...
# 393         Abnorml\tAbnormal Sale -  trade, forecl...
# 394                   AdjLand\tAdjoining Land Purchase
# 395         Alloca\tAllocation - two linked propert...
# 396                Family\tSale between family members
# 397         Partial\tHome was not completed when la...
#
# [398 rows x 1 columns]

# %%
# with open('data/data_description.txt', 'r') as f:
#     data = f.readlines()
# data

# %%
# # Ploting a histogram to have an overview of the dataset

# import matplotlib.pyplot as plt
# import numpy as np


# plt.hist(df)
# plt.show(df)

# %%
# # Show the max column width to understand the dataset

# # used the - sep = 'r' - argument to define the separator
# df = pd.read_csv('data/data_description.txt', sep='\r')

# # displays the max column width for the 1st 20 rows

# pd.set_option('display.max_colwidth', None)
# df.head(20)

# %%
# df.info()

# %%
# df.isna()

# %%
# Converting txt to csv to try and understand the dataset

# df.to_csv('data/data_description.csv',
#              index= None)
# df

# %%
# df = pd.read_csv('data/ames.csv', index_col=0)
# df.head()

# %%
#df.columns

# %%
#df.Age.sort_values(ascending = True)

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Your code here

# importing pandas library and matplotlib

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Your code here

# Assigning the loaded file ames.csv to the variable df

df = pd.read_csv('data/ames.csv', index_col=0)

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes

df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Checking the data frame columns with the first 5 rows
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 4          Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 5          Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# This is to identify the range of years for the dataset for ploting

year_sold = df.YrSold
print (f"The latest year a house was sold is {max(year_sold)} and the earliest is {min(year_sold)}.")
# Out:
# The latest year a house was sold is 2010 and the earliest is 2006.

# %%
# Your code here
# Declare the variable x and assign it to the data from SalePrice in our DataFrame (df)
x = df.SalePrice

# Used 100 bins to have a clear view of the outliers

plt.hist(x, bins = 100, edgecolor = 'black')

# Setting the axes lables and the plot title
plt.xlabel('Sale Price (USD)')
plt.ylabel('Number of houses')
plt.title('Sale Prices for houses in Ames, IA, between 2006 - 2010')
plt.axvline(x.mean(), color='black', linewidth = 2)

min_ylim, max_ylim = plt.ylim()

# plot the mean value next to the vertical line showing mean.

plt.text(x.mean()*1.1, max_ylim*0.9, 'Mean:{:.2f}'.format(x.mean()))
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here

# Below print function using the f string method prints out the mean, median and standard deviation
# using the :.2f to convert the int mean and std to 2 decimal places floats
print(f"The mean sale price is,USD {df.SalePrice.mean():.2f}, the median is USD {df.SalePrice.median():.2f} and Standard Deviation is USD {df.SalePrice.std():.2f}")
# Out:
# The mean sale price is,USD 180921.20, the median is USD 163000.00 and Standard Deviation is USD 79442.50

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# # Replace None with appropriate text
# ## Interpretation of the measure of cenral tendancies on the sale price of the houses in the dataset.
#
# There are little outliers in the dataset with a majority of the houses ranging between the USD 160,000 - 180,000 price mark.

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# Your code here

# Retrieving the data from column TotRmsAbvGrd and assgning it to the variable y

y = df.TotRmsAbvGrd

# Used 100 bins to have a clear view of the outliers

plt.hist(y, bins = 100, edgecolor = 'black')

plt.xlabel('Total Rooms Above Ground')
plt.ylabel('Number of houses')
plt.title('Total rooms above ground \n for houses in Ames, IA, between 2006 - 2010')
plt.axvline(y.mean(), color='green', linewidth = 2)

min_ylim, max_ylim = plt.ylim()

# plot the mean value next to the vertical line showing mean.

plt.text(y.mean()*1.05, max_ylim*0.9, 'Mean:{:.2f}'.format(y.mean()), color = 'green')
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here

# below print function using the f string method prints out the mean, median and standard deviation
# using the :.2f to convert the int mean and std to 2 decimal places floats
print(f"The mean total rooms above ground is, {df.TotRmsAbvGrd.mean():.2f}, the median is {df.TotRmsAbvGrd.median():.2f} and Standard Deviation is {df.TotRmsAbvGrd.std():.2f} rooms.")
# Out:
# The mean total rooms above ground is, 6.52, the median is 6.00 and Standard Deviation is 1.63 rooms.

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# # Replace None with appropriate text
# ## Interpretation of the measure of cenral tendancies on the rooms above ground of the dataset.
#
# Most of the houses in the area have 5 rooms and above, which are above ground since the deviation is also very low from the mean of 6.52.

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# Retrieving the data from column OverallCond and assgning it to the variable z

z = df.OverallCond
z
# Out:
# Id
# 1       5
# 2       8
# 3       5
# 4       5
# 5       5
#        ..
# 1456    5
# 1457    6
# 1458    9
# 1459    6
# 1460    6
# Name: OverallCond, Length: 1460, dtype: int64

# %%
# Your code here

# initializing the dataframe TotRmsAbvGrd to the variable z
z = df.OverallCond

# Used 10 bins to have a clear view of the outliers

plt.hist(z,bins = 100, edgecolor = 'black')

plt.xlabel('Overall Condition \n scale of 1 to 9')
plt.ylabel('Number of houses')
plt.title('Overall Condition \n of houses in Ames, IA, between 2006 - 2010')
plt.axvline(z.mean(), color='green', linewidth = 2)

min_ylim, max_ylim = plt.ylim()

# plot the mean value next to the vertical line showing mean.

plt.text(z.mean()*1.05, max_ylim*0.9, 'Mean:{:.2f}'.format(z.mean()), color = 'green')
plt.show()

# %%
# Displaying the maximum column

pd.set_option('display.max_columns', None)

# Calling the 2 columns SalePrice and OverallCond

df.loc[:, ['SalePrice', 'OverallCond']]
# Out:
#       SalePrice  OverallCond
# Id
# 1        208500            5
# 2        181500            8
# 3        223500            5
# 4        140000            5
# 5        250000            5
# ...         ...          ...
# 1456     175000            5
# 1457     210000            6
# 1458     266500            9
# 1459     142125            6
# 1460     147500            6
#
# [1460 rows x 2 columns]

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here

# below print function using the f string method prints out the mean, median and standard deviation
# using the :.2f to convert the int mean and std to 2 decimal places floats
print(f"The mean of the overall condition is, {df.OverallCond.mean():.2f}, the median is {df.OverallCond.median():.2f} and Standard Deviation is {df.OverallCond.std():.2f}.")
# Out:
# The mean of the overall condition is, 5.58, the median is 5.00 and Standard Deviation is 1.11.

# %% [markdown]
# In the cell below, interpret the above information.

# %% [markdown]
# # Replace None with appropriate text
# ## Interpretation of the measure of cenral tendancies on the overall condition of the dataset.
#
# Most houses have been rated within the mean with a low deviation. This would mean that most houses meet the rating of above 4 points.

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
# Replace None with appropriate code
below_average_condition = df.loc[df.OverallCond < 5]
#below_average_condition

average_condition = df.loc[df.OverallCond == 5]
#average_condition

above_average_condition = df.loc[df.OverallCond > 5]
#above_average_condition

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %% [markdown]
# # Replace None with appropriate text
#
# ## My interpretation of the plot on Distribution of Sale Price Grouped by Condition
#     What is suprising is that average condition houses are more prefered and are highly priced than the above average. Quite strange and contrary to popular belief of the better the Condition of a house the more priced it would be.

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Your code here

# df.corr()

# df.loc[df.corr()['SalePrice'] > 0.2]
# df['Most positive correlation'] = df.groupby('SalePrice')[df.corr].transform(lambda x: x.rank(ascending=False))
# most_corr = df.groupby('SalePrice').filter(lambda x: x['SalePrice'].corr() >= 0.6)
# most_corr

# correlation of SalePrice against all other columns
corr_matrix = df.corr()['SalePrice']
corr_matrix

# Correlation sorted to identify the highest and least correlation
corr_SalePrice = corr_matrix.sort_values(ascending= False)
corr_SalePrice

# With the descending sorting, we have the most posively correlated column come first
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# ...

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Your code here

# Correlation sorted to identify the highest and least correlation

corr_SalePrice = corr_matrix.sort_values(ascending= True)
corr_SalePrice

# With the ascending sorting, the most negatively correlated column comes first.
# Out:
# Age             -0.523350
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# ...

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(30,10))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df.OverallQual,
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df.Age,
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title('Distribution of Correlation between \n Sale Price and the Overall Quality')
ax1.set_xlabel('Overall Quality')
ax1.set_ylabel("Sale Price (USD)")
ax2.set_title('Distribution of Correlation between \n Sale Price and the Age')
ax2.set_xlabel('Age(Years)')

# improves the x axis to display every 5th stick for visibility

ax2.set_xticks(ax2.get_xticks()[::10])
ax2.set_ylabel("Sale Price(USD)");

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %% [markdown]
# # Replace None with appropriate text
#
# ## Interpretation of the plots
#
# ### Sale Price vs Overall Quality
# * There are less outliers in the highest and lowest quality ratings
# * 50% of the highest rating of 10 points lie between the USD 350,000 and 450,000 sale price.
#
# ### Sale Price vs Age
# * House that are 73 years had a high sales with 50% of the sale price ranging between USD 60,000 and 250,000
# * Houses above 100 years had few sales with many outliers in the data set

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: YrSold, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %% [markdown]
# # Replace None with appropriate text
#
# # Interpretation of the scatter plot above
# From the scatter plot above, I can deduce below points.
# * Newer houses have a higher preference by buyers and are highly priced.
# * Very old houses, ranging above 100 years are not prefered and are lowly priced
# * Houses that are 30 - 60 years are prefered by many buyers, factors contributing to this preference could be their price and also they have stood the test of time.
# * There are outliers on both age extremes with houses older than 100 years being highly priced. A factor could be their location and overall condition of the house.
# * Other outliers are newer house, ranging 5 - 10yrs that are highly priced, they could be highly priced due to their location and overall condition.

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset. You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.
